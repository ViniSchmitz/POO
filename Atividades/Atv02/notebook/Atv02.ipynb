// %% [markdown]
// # Atv02

// %% [markdown]
// Exibir a mensagem “Informe um inteiro: “, deixando o cursor na mesma linha

// %%
Scanner teclado = new Scanner(System.in);
System.out.print("informe um numero inteiro: ");

// %% [markdown]
// Atribuir o produto das variáveis b e c para a variável a

// %%
Scanner teclado = new Scanner(System.in);
int b = teclado.nextInt();
int c = teclado.nextInt();
float a = b*c;
System.out.println(a);
// Out:
// cannot find symbol
//   symbol:   class Scanner
//   location: class com.twosigma.beaker.javash.bkr8ca58279.BeakerWrapperClass1261714175Id8675f57184c34216869fcc47d7fb74e4
//  Scanner teclado = new Scanner(System.
//  ^      ^
//
// cannot find symbol
//   symbol:   class Scanner
//   location: class com.twosigma.beaker.javash.bkr8ca58279.BeakerWrapperClass1261714175Id8675f57184c34216869fcc47d7fb74e4
//  Scanner teclado = new Scanner(System.in)
//                        ^      ^

// %% [markdown]
// Demonstrar a execução do cálculo e utilizar um comentário para afirmar que é um programa de exemplo de folha de pagamento.

// %%
System.out.println(a);
System.out.println("O programa executa um calculo de exemplo de folha de pagamento.");
// Out:
// cannot find symbol
//   symbol:   variable a
//   location: class com.twosigma.beaker.javash.bkr8ca58279.BeakerWrapperClass1261714175Id332630018e164002802baedfc4ddd188
//  System.out.println(a)
//                     ^^
